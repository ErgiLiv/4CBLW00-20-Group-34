# %% [markdown]
# # 02 EDA – Burglary sanity‑check
# Quick exploratory notebook that:
# 1. Plots London‑wide monthly burglary totals
# 2. Shows the Top‑20 wards (cumulative 2013‑2025)
# 3. Draws a choropleth of the latest month
#
# Data sources (already generated by *ingest_burglary.py*):
# * `data_cache/processed/ward_month_burglary.parquet`
# * `data_cache/lookups/wards_2024.geojson`

# %%
# %pip install pandas geopandas matplotlib seaborn mapclassify plotly
# Out:
# Requirement already satisfied: pandas in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: geopandas in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: matplotlib in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: mapclassify in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (2.8.1)
# Requirement already satisfied: plotly in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (6.0.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from geopandas) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: networkx>=2.7 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from mapclassify) (3.4.2)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from mapclassify) (1.15.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from plotly) (1.37.1)
# Requirement already satisfied: certifi in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from scikit-learn>=1.0->mapclassify) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ergi livanaj\desktop\university\year 2\quarter 4\4cblw00-20 (jbg050 data challenge 2)\4cblw00-20-group-34\venv\lib\site-packages (from scikit-learn>=1.0->mapclassify) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib, pandas as pd, geopandas as gpd, matplotlib.pyplot as plt, seaborn as sns

REPO      = pathlib.Path('..').resolve()  # assumes notebook in notebooks/
PROCESSED = REPO / 'data_cache/processed'
LOOKUPS   = REPO / 'data_cache/lookups'
PANEL_FP  = PROCESSED / 'ward_month_burglary.parquet'
GEOJSON   = LOOKUPS / 'wards_2024.geojson'
FIGDIR    = pathlib.Path('figures'); FIGDIR.mkdir(exist_ok=True)

wm = pd.read_parquet(PANEL_FP)
wards = gpd.read_file(GEOJSON)
print(f'Data loaded: {len(wm):,} ward‑month rows')
# Out:
# Data loaded: 97,356 ward‑month rows

# %% [markdown]
# ## 1 · London‑wide monthly totals

# %%
monthly = wm.groupby('Month')['burglaries'].sum()
plt.figure(figsize=(12,4))
monthly.plot()
plt.title('London residential burglary – monthly totals')
plt.ylabel('Number of burglaries')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 2 · Top‑20 wards (cumulative 2013‑2025)

# %%
top20 = wm.groupby('WD24NM')['burglaries'].sum().nlargest(20)
plt.figure(figsize=(12,6))
sns.barplot(y=top20.index, x=top20.values, orient='h', palette='viridis')
plt.title('Top‑20 wards by total burglaries (Dec 2013 – Feb 2025)')
plt.xlabel('Total burglaries')
plt.tight_layout(); plt.show()
# Out:
# C:\Users\Ergi Livanaj\AppData\Local\Temp\ipykernel_21760\691486711.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top20.index, x=top20.values, orient='h', palette='viridis')

# %% [markdown]
# ## 3 · Choropleth of latest month

# %%
latest_month = wm['Month'].max()
print('Latest month in data: ', latest_month.date())
latest = wm[wm['Month'] == latest_month]
latest_gdf = wards[['WD24CD', 'geometry']].merge(latest, on='WD24CD', how='left')
ax = latest_gdf.plot(column='burglaries', cmap='OrRd', scheme='quantiles', legend=True,
                     figsize=(12,12), edgecolor='black', linewidth=0.5)
ax.set_axis_off()
ax.set_title(f"Residential burglaries – {latest_month.strftime('%b %Y')}")
plt.tight_layout(); plt.show()
# Out:
# Latest month in data:  2025-02-01
